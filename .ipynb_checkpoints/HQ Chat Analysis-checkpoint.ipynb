# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
import re

# define regex pattern for chat line
pattern = r'^(\d{2}\/\d{2}\/\d{4}),\s(\d{2}:\d{2})\s-\s(.*?):\s(.*)$'

# create empty dataframe
df = pd.DataFrame(columns=["date", "time", "user", "message"])

# read file line by line
with open("HQ.txt", encoding='utf-8') as f:
    for line in f:
        # match regex pattern with line
        match = re.match(pattern, line)
        if match:
            # extract groups from match
            groups = match.groups()
            # add row to dataframe
            df = df.append({"date": groups[0], "time": groups[1], "user": groups[2], "message": groups[3]}, ignore_index=True)

# print dataframe
df
# Out:
#              date   time            user  \
# 0      19/01/2022  13:00           Ngabi
# 1      19/01/2022  13:00           Ngabi
# 2      19/01/2022  13:01           Ambro
# 3      19/01/2022  13:01           Ambro
# 4      19/01/2022  13:02           Ngabi
# ...           ...    ...             ...
# 39967  01/03/2023  14:08           Ambro
# 39968  01/03/2023  14:08           Ambro
# 39969  01/03/2023  14:10           Ambro
# 39970  01/03/2023  14:14  Daniel Charles
# 39971  01/03/2023  14:14           Ambro
#
#                                                  message
# 0      You want a long distance silent disco with ur ...
# 1                     Danny is ur power disturbing sir ?
# 2                                                 Hehehe
# 3                                                  Bambi
# 4                  Man ffe ka power level Kali on de low
# ...                                                  ...
# 39967  Actually kempten will officially be opened for...
# 39968                            For now let is just eat
# 39969                                    <Media omitted>
# 39970                                       Btw leave me
# 39971                                    <Media omitted>
#
# [39972 rows x 4 columns]

# %%
# convert date column to datetime data type
df['date'] = pd.to_datetime(df['date'])

# extract year and month
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df
# Out:
#             date   time            user  \
# 0     2022-01-19  13:00           Ngabi
# 1     2022-01-19  13:00           Ngabi
# 2     2022-01-19  13:01           Ambro
# 3     2022-01-19  13:01           Ambro
# 4     2022-01-19  13:02           Ngabi
# ...          ...    ...             ...
# 39967 2023-01-03  14:08           Ambro
# 39968 2023-01-03  14:08           Ambro
# 39969 2023-01-03  14:10           Ambro
# 39970 2023-01-03  14:14  Daniel Charles
# 39971 2023-01-03  14:14           Ambro
#
#                                                  message  year  month
# 0      You want a long distance silent disco with ur ...  2022      1
# 1                     Danny is ur power disturbing sir ?  2022      1
# 2                                                 Hehehe  2022      1
# 3                                                  Bambi  2022      1
# 4                  Man ffe ka power level Kali on de low  2022      1
# ...                                                  ...   ...    ...
# 39967  Actually kempten will officially be opened for...  2023      1
# 39968                            For now let is just eat  2023      1
# 39969                                    <Media omitted>  2023      1
# 39970                                       Btw leave me  2023      1
# 39971                                    <Media omitted>  2023      1
#
# [39972 rows x 6 columns]

# %%
df['user'].unique()
# Out:
# array(['Ngabi', 'Ambro', 'Saga', 'Inno Samurai', 'Dannie3', 'Pato',
#        'Oma Mtn', 'Sh@eks', 'Emmaa', 'Daniel Charles'], dtype=object)

# %%
df['user'] = df['user'].replace({'Daniel Charles':'D C','Ngabi': 'N B', 'Ambro': 'O A','Saga': 'Sa Ga','Inno Samurai': 'E I P','Pato': 'R P','Oma Mtn': 'O J','Emmaa': 'E E'})

# %%
df['user'].unique()
# Out:
# array(['N B', 'O A', 'Sa Ga', 'E I P', 'Dannie3', 'R P', 'O J', 'Sh@eks',
#        'E E', 'D C'], dtype=object)

# %% [markdown]
# # Exploratory Data Analysis

# %%
# extract hour from time column
df['hour'] = pd.to_datetime(df['time']).dt.hour

# group by hour and count number of messages
hourly_counts = df.groupby('hour')['message'].count()

# plot results
plt.plot(hourly_counts.index, hourly_counts.values)
plt.title('Number of messages by hour of day')
plt.xlabel('Hour of day')
plt.ylabel('Number of messages')
plt.show()

# %% [markdown]
# # Most Active Users

# %%
df['user'].value_counts().plot(kind = 'barh')
# Out:
# <Axes: >

# %% [markdown]
# # Sentiment Analysis

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#downloading vader lexicon
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\danie\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sentiment_analyzer = SentimentIntensityAnalyzer()

# %%
sentiment_analyzer.polarity_scores('Somehow I wish that were true 😂')
# Out:
# {'neg': 0.0, 'neu': 0.353, 'pos': 0.647, 'compound': 0.6705}

# %%
df.iloc[0]['message']
# Out:
# 'You want a long distance silent disco with ur baby, join Spotify and create a group and invite ur baby. Thanks me later'

# %%
sentiment_analyzer.polarity_scores(df.iloc[0]['message'])
# Out:
# {'neg': 0.0, 'neu': 0.613, 'pos': 0.387, 'compound': 0.7964}

# %%
df['Scores'] = df['message'].apply(lambda message: sentiment_analyzer.polarity_scores(message))

# %%
df['compound'] = df['Scores'].apply(lambda d: d['compound'])

# %%
df['Sentiment'] = df['compound'].apply(lambda score: 'Positive' if score > 0 else ('Neutral' if score == 0 else 'Negative'))

# %%
df.head()
# Out:
#         date   time user                                            message  \
# 0 2022-01-19  13:00  N B  You want a long distance silent disco with ur ...
# 1 2022-01-19  13:00  N B                 Danny is ur power disturbing sir ?
# 2 2022-01-19  13:01  O A                                             Hehehe
# 3 2022-01-19  13:01  O A                                              Bambi
# 4 2022-01-19  13:02  N B              Man ffe ka power level Kali on de low
#
#    year  month  hour                                             Scores  \
# 0  2022      1    13  {'neg': 0.0, 'neu': 0.613, 'pos': 0.387, 'comp...
# 1  2022      1    13  {'neg': 0.398, 'neu': 0.602, 'pos': 0.0, 'comp...
# 2  2022      1    13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  2022      1    13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  2022      1    13  {'neg': 0.208, 'neu': 0.792, 'pos': 0.0, 'comp...
#
#    compound Sentiment
# 0    0.7964  Positive
# 1   -0.5106  Negative
# 2    0.0000   Neutral
# 3    0.0000   Neutral
# 4   -0.2732  Negative

# %%
df = df.rename(columns={'compound': 'Score'})
df = df[['date', 'time', 'user', 'message', 'Sentiment', 'Score', 'hour','month', 'year']]
df
# Out:
#             date   time user  \
# 0     2022-01-19  13:00  N B
# 1     2022-01-19  13:00  N B
# 2     2022-01-19  13:01  O A
# 3     2022-01-19  13:01  O A
# 4     2022-01-19  13:02  N B
# ...          ...    ...  ...
# 39967 2023-01-03  14:08  O A
# 39968 2023-01-03  14:08  O A
# 39969 2023-01-03  14:10  O A
# 39970 2023-01-03  14:14  D C
# 39971 2023-01-03  14:14  O A
#
#                                                  message Sentiment   Score  \
# 0      You want a long distance silent disco with ur ...  Positive  0.7964
# 1                     Danny is ur power disturbing sir ?  Negative -0.5106
# 2                                                 Hehehe   Neutral  0.0000
# 3                                                  Bambi   Neutral  0.0000
# 4                  Man ffe ka power level Kali on de low  Negative -0.2732
# ...                                                  ...       ...     ...
# 39967  Actually kempten will officially be opened for...   Neutral  0.0000
# 39968                            For now let is just eat   Neutral  0.0000
# 39969                                    <Media omitted>   Neutral  0.0000
# 39970                                       Btw leave me  Negative -0.0516
# 39971                                    <Media omitted>   Neutral  0.0000
#
#        hour  month  year
# 0        13      1  2022
# 1        13      1  2022
# 2        13      1  2022
# 3        13      1  2022
# 4        13      1  2022
# ...     ...    ...   ...
# 39967    14      1  2023
# 39968    14      1  2023
# 39969    14      1  2023
# 39970    14      1  2023
# 39971    14      1  2023
#
# [39972 rows x 9 columns]

# %%
# df.to_csv('Head Quarters.csv')

# %%
df['Sentiment'].value_counts()
# Out:
# Neutral     32688
# Positive     4069
# Negative     3215
# Name: Sentiment, dtype: int64

# %%
df['Sentiment'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='Sentiment'>

# %% [markdown]
# # Hidden Emotions

# %%
df.groupby('user').mean()
# Out:
#             Score       hour     month         year
# user
# D C      0.002503  14.747366  6.483923  2022.283977
# Dannie3  0.001227  15.090802  5.983250  2022.194534
# E E      0.013677  15.740484  6.076125  2022.107266
# E I P    0.004755  14.688073  5.936138  2022.149248
# N B      0.007635  14.488667  5.896386  2022.133661
# O A      0.014579  14.468665  5.945605  2022.164677
# O J      0.010808  14.173021  6.010264  2022.272727
# R P      0.005741  14.349451  6.068446  2022.062794
# Sa Ga   -0.004087  15.565568  4.449899  2022.088769
# Sh@eks   0.004317  14.449275  2.787440  2022.270531

# %%
year_month = df.groupby(['user','month', 'year']).mean().reset_index()
year_month
# Out:
#        user  month  year     Score       hour
# 0       D C      1  2022  0.031202  12.812500
# 1       D C      1  2023 -0.000869  14.625000
# 2       D C      2  2022  0.011700  15.693333
# 3       D C      2  2023 -0.009902  13.375375
# 4       D C      3  2022 -0.006600  15.666667
# ..      ...    ...   ...       ...        ...
# 211  Sh@eks      7  2022  0.000000   7.000000
# 212  Sh@eks      8  2022  0.000000  13.857143
# 213  Sh@eks     10  2022 -0.048571  20.571429
# 214  Sh@eks     11  2022  0.000000  12.666667
# 215  Sh@eks     12  2022  0.000000  14.500000
#
# [216 rows x 5 columns]

# %%
df['user'].unique()
# Out:
# array(['N B', 'O A', 'Sa Ga', 'E I P', 'Dannie3', 'R P', 'O J', 'Sh@eks',
#        'E E', 'D C'], dtype=object)

# %%
streetKing = year_month[year_month['user'] == 'N B']['Score'].values
backBreaker = year_month[year_month['user'] == 'O A']['Score'].values
mrVulnerable = year_month[year_month['user'] == 'Sa Ga']['Score'].values
blackSmoke = year_month[year_month['user'] == 'E I P']['Score'].values
dannie3 = year_month[year_month['user'] == 'Dannie3']['Score'].values
certifiedLoverBoy = year_month[year_month['user'] == 'R P']['Score'].values
tipStar = year_month[year_month['user'] == 'O J']['Score'].values
shaeks = year_month[year_month['user'] == 'Shaeks']['Score'].values
silentAssassin = year_month[year_month['user'] == 'E E']['Score'].values
uncleWaffles = year_month[year_month['user'] == 'D C']['Score'].values

# %%
plt.figure(figsize = (20,10))
plt.plot(streetKing, label='N B')
plt.plot(dannie3, label='Dannie3')
plt.plot(backBreaker, label='O A')
plt.plot(mrVulnerable, label='E I P')
plt.plot(blackSmoke, label='Sa Ga')
plt.plot(certifiedLoverBoy, label='R P')
plt.plot(tipStar, label='O J')
plt.plot(shaeks, label='Sh@eks')
plt.plot(silentAssassin, label='E E')
plt.plot(uncleWaffles, label='D C')
plt.legend()

# %%
# year_month.to_csv('Average Sentiment Score.csv')
